# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd = pd.read_csv('NBA_player_of_the_week.csv')

# %%
pd.head()
# Out:
#    Active season                  Player                  Team Conference  \
# 0              0  Micheal Ray Richardson       New Jersey Nets        NaN
# 1              0             Derek Smith  Los Angeles Clippers        NaN
# 2              0             Calvin Natt        Denver Nuggets        NaN
# 3              0     Kareem Abdul-Jabbar    Los Angeles Lakers        NaN
# 4              0              Larry Bird        Boston Celtics        NaN
#
#            Date Position Height  Weight  Age  Draft Year  Seasons in league  \
# 0  Apr 14, 1985       PG    6-5     189   29        1978                  6
# 1   Apr 7, 1985       SG    6-6     205   23        1982                  2
# 2   Apr 1, 1985        F    6-6     220   28        1979                  5
# 3  Mar 24, 1985        C    7-2     225   37        1969                 15
# 4  Mar 17, 1985       SF    6-9     220   28        1978                  5
#
#       Season  Season short  Real_value
# ...

# %%
pd.describe()
# Out:
#        Active season       Height       Weight          Age   Draft Year  \
# count    1155.000000  1155.000000  1155.000000  1155.000000  1155.000000
# mean        0.008658     6.595238   226.038095    26.772294  1997.372294
# std         0.092685     0.309766    31.590100     3.393478     9.442516
# min         0.000000     5.750000   150.000000    19.000000  1969.000000
# 25%         0.000000     6.333333   205.000000    24.000000  1991.000000
# 50%         0.000000     6.583333   225.000000    26.000000  1998.000000
# 75%         0.000000     6.833333   250.000000    29.000000  2004.000000
# max         1.000000     7.500000   325.000000    40.000000  2016.000000
#
#        Seasons in league  Season short   Real_value
# count        1155.000000   1155.000000  1155.000000
# mean            5.870130   2004.339394     0.666234
# std             3.265082      9.485598     0.235651
# min             0.000000   1985.000000     0.500000
# ...

# %%
sns.set(style = "whitegrid", rc = {"figure.figsize": (10, 8)})

# %%
#Choose one variable and plot that variable four different ways.

# %%
sns.distplot(pd['Weight'],bins=25,kde=False)

# %%
sns.distplot(pd['Height'],bins=20,kde=False)

# %%
sns.distplot(pd['Weight'],hist=False)
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.boxplot(x=pd['Weight'])

# %%
def height_convert(x):
    a = x.split('-')
    return int(a[0]) + int(a[1])/12

# %%
height_convert('6-5')
# Out:
# 6.416666666666667

# %%
pd['Height'] = pd['Height'].apply(height_convert)

# %%
pd.head()
# Out:
#    Active season                  Player                  Team Conference  \
# 0              0  Micheal Ray Richardson       New Jersey Nets        NaN
# 1              0             Derek Smith  Los Angeles Clippers        NaN
# 2              0             Calvin Natt        Denver Nuggets        NaN
# 3              0     Kareem Abdul-Jabbar    Los Angeles Lakers        NaN
# 4              0              Larry Bird        Boston Celtics        NaN
#
#            Date Position    Height  Weight  Age  Draft Year  \
# 0  Apr 14, 1985       PG  6.416667     189   29        1978
# 1   Apr 7, 1985       SG  6.500000     205   23        1982
# 2   Apr 1, 1985        F  6.500000     220   28        1979
# 3  Mar 24, 1985        C  7.166667     225   37        1969
# 4  Mar 17, 1985       SF  6.750000     220   28        1978
#
#    Seasons in league     Season  Season short  Real_value
# 0                  6  1984-1985          1985         1.0
# ...

# %%
#Choose two continuous variables, and plot them three different ways.

# %%
sns.jointplot(x=pd['Height'], y=pd['Weight'])
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x=pd['Height'], y=pd['Weight'], kind='hex')
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x=pd['Height'], y=pd['Weight'], kind='kde')
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.jointplot(x=pd['Draft Year'], y=pd['Height'])
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Choose one continuous variable and one categorical variable, and plot them six different ways.

# %%
sns.pairplot(pd)

# %%
sns.catplot(x='Position', y='Height', data=pd)

# %%
sns.catplot(x='Position', y='Height', data=pd, kind='swarm')

# %%
sns.catplot(x='Position', y='Height', data=pd, hue='Draft Year', order=['PG','G','SG','G-F','GF','SF','F','PF','FC','F-C','C'], palette='deep')

# %%
sns.catplot(x='Position', y='Height', data=pd, kind='violin', order=['PG','G','SG','G-F','GF','SF','F','PF','FC','F-C','C'])
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x='Position', y='Height', data=pd, kind='bar', order=['PG','G','SG','G-F','GF','SF','F','PF','FC','F-C','C'])
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.catplot(x='Position', y='Height', data=pd, kind='box', order=['PG','G','SG','G-F','GF','SF','F','PF','FC','F-C','C'])

# %%
sns.lmplot(x='Weight', y='Height', data=pd)
# Out:
# C:\Users\diegofvargas\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x='Team', data=pd)
g.set_xticklabels(g.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'New Jersey Nets'),
#  Text(0, 0, 'Los Angeles Clippers'),
#  Text(0, 0, 'Denver Nuggets'),
#  Text(0, 0, 'Los Angeles Lakers'),
#  Text(0, 0, 'Boston Celtics'),
#  Text(0, 0, 'Utah Jazz'),
#  Text(0, 0, 'Golden State Warriors'),
#  Text(0, 0, 'Dallas Mavericks'),
#  Text(0, 0, 'Atlanta Hawks'),
#  Text(0, 0, 'Washington Bullets'),
#  Text(0, 0, 'Chicago Bulls'),
#  Text(0, 0, 'Cleveland Cavaliers'),
#  Text(0, 0, 'Detroit Pistons'),
#  Text(0, 0, 'Milwaukee Bucks'),
#  Text(0, 0, 'Seattle SuperSonics'),
#  Text(0, 0, 'New York Knicks'),
#  Text(0, 0, 'Philadelphia Sixers'),
#  Text(0, 0, 'Phoenix Suns'),
#  Text(0, 0, 'Indiana Pacers'),
#  Text(0, 0, 'Portland Trail Blazers'),
#  Text(0, 0, 'San Antonio Spurs'),
#  Text(0, 0, 'Sacramento Kings'),
#  Text(0, 0, 'Houston Rockets'),
#  Text(0, 0, 'Miami Heat'),
#  Text(0, 0, 'Orlando Magic'),
#  Text(0, 0, 'Charlotte Hornets'),
#  Text(0, 0, 'Minnesota Timberwolves'),
#  Text(0, 0, 'Toronto Raptors'),
# ...

# %%
plt.figure(figsize=(15,8))
g = sns.countplot(x='Position', data=pd, order=['PG','G','SG','G-F','GF','SF','F','PF','FC','F-C','C'])
g.set_xticklabels(g.get_xticklabels(),rotation=90)
# Out:
# [Text(0, 0, 'PG'),
#  Text(0, 0, 'G'),
#  Text(0, 0, 'SG'),
#  Text(0, 0, 'G-F'),
#  Text(0, 0, 'GF'),
#  Text(0, 0, 'SF'),
#  Text(0, 0, 'F'),
#  Text(0, 0, 'PF'),
#  Text(0, 0, 'FC'),
#  Text(0, 0, 'F-C'),
#  Text(0, 0, 'C')]
