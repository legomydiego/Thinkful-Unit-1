# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
pd = pd.read_csv('World Happiness 2017.csv')

# %% [markdown]
# Context
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
# Content
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
# Inspiration
# What countries or regions rank the highest in overall happiness and each of the six factors contributing to happiness? How did country ranks or scores change between the 2015 and 2016 as well as the 2016 and 2017 reports? Did any country experience a significant increase or decrease in happiness?
#
# What is Dystopia?
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
# What are the residuals?
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average 2014-2016 life evaluations. These residuals have an average value of approximately zero over the whole set of countries. Figure 2.2 shows the average residual for each country when the equation in Table 2.1 is applied to average 2014- 2016 data for the six variables in that country. We combine these residuals with the estimate for life evaluations in Dystopia so that the combined bar will always have positive values. As can be seen in Figure 2.2, although some life evaluation residuals are quite large, occasionally exceeding one point on the scale from 0 to 10, they are always much smaller than the calculated value in Dystopia, where the average life is rated at 1.85 on the 0 to 10 scale.
#
# What do the columns succeeding the Happiness Score(like Family, Generosity, etc.) describe?
#
# The following columns: GDP per Capita, Family, Life Expectancy, Freedom, Generosity, Trust Government Corruption describe the extent to which these factors contribute in evaluating the happiness in each country. The Dystopia Residual metric actually is the Dystopia Happiness Score(1.85) + the Residual value or the unexplained value for each country as stated in the previous answer.
#
# If you add all these factors up, you get the happiness score so it might be un-reliable to model them to predict Happiness Scores.

# %%
pd.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# ...

# %%
pd.describe()
# Out:
#        Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# count      155.000000       155.000000    155.000000   155.000000
# mean        78.000000         5.354019      5.452326     5.255713
# std         44.888751         1.131230      1.118542     1.145030
# min          1.000000         2.693000      2.864884     2.521116
# 25%         39.500000         4.505500      4.608172     4.374955
# 50%         78.000000         5.279000      5.370032     5.193152
# 75%        116.500000         6.101500      6.194600     6.006527
# max        155.000000         7.537000      7.622030     7.479556
#
#        Economy..GDP.per.Capita.      Family  Health..Life.Expectancy.  \
# count                155.000000  155.000000                155.000000
# mean                   0.984718    1.188898                  0.551341
# std                    0.420793    0.287263                  0.237073
# min                    0.000000    0.000000                  0.000000
# ...

# %% [markdown]
# I found the conclusions from this data set very interesting it first came out a few years ago. Happiness is a very different of measure of well being vs the usually cited gdp. The results make sense, however happiness is a very subjective concept to quantify. It means very different things depending on a multitude of factors. My main questions are:
#     1)What factors count the most for Americans perception of happiness?
#     2)What factors count the most for Dominicans (where I was born) perception of happiness?
#     3)What do happier countries value more vs unhappier ones?
#     4)What's the correlation between GDP and happiness?

# %%
pd[pd['Country']=='United States']
# Out:
#           Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 13  United States              14            6.993      7.074657     6.911343
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 13                  1.546259  1.419921                  0.774287  0.505741
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 13    0.392579                       0.135639           2.218113

# %% [markdown]
# For the United States, the economy is the top contributor to happiness, followed closely by family. Both values are significantly above the global mean, the economy is actually above 1 std from the mean. Surprised to see freedom isn't higher

# %%
pd[pd['Country']=='Dominican Republic']
# Out:
#                Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 85  Dominican Republic              86             5.23      5.349061
#
#     Whisker.low  Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.  \
# 85     5.110939                  1.079374  1.402417                  0.574874
#
#     Freedom  Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 85  0.55259    0.186968                       0.113945           1.319465

# %% [markdown]
# The Dominican Republic's biggest contributor to its happiness score is the family value, very similar to the US. However, the value for the economy is much lower, which makes sense, since the economy is much weaker. Additionaly, the freedom and corruption scores are very similar, which doesn't make sense to me at all, because corruption is much more rampant and laws aren't as fair or clear as in the US. Guess its perception and bias.

# %%
sns.set(style = "whitegrid", rc = {"figure.figsize": (10, 8)})

# %%
#Initial visualitazions

# %%
sns.distplot(pd['Happiness.Score'], bins=20, kde=False)

# %%
sns.distplot(pd['Economy..GDP.per.Capita.'], bins=20, kde=False)

# %%
sns.distplot(pd['Family'], bins=20, kde=False)

# %%
sns.distplot(pd['Health..Life.Expectancy.'], bins=20, kde=False)

# %%
sns.distplot(pd['Freedom'], bins=20, kde=False)

# %%
sns.distplot(pd['Generosity'], bins=20, kde=False)

# %%
sns.distplot(pd['Trust..Government.Corruption.'], bins=20, kde=False)

# %% [markdown]
# From the graphs above, it seems like the distributions are slanted to the right, except for generosity and corruption. Family is the biggest contributor on average to happiness since it has the highest mean and is very slanted to the right. The economy is a close second, which makes sense, since poverty is one of the biggest issues we face. In summary, a significant percentage of the global population is not satisfied with the state of perceived generosity and corruption in their countries. On the other hand, strong family ties, a robust economy and to a lesser degree healthcare add to global happiness.

# %% [markdown]
# Correlation Table

# %%
corr_table = pd.drop(['Happiness.Rank','Whisker.high','Whisker.low','Dystopia.Residual'],axis=1).corr()

# %%
sns.heatmap(corr_table, annot=True, cmap='coolwarm')

# %% [markdown]
# The three values with the highest correlations with the happiness score are economy, health and family, in that order. Freedom and corruption(to a lesser degree) have positive correlations as well, but generosity is close to being uncorrelated to happiness. Other correlations to note are health vs GDP, family vs GDP and health vs family, which are all pretty high.
#
# Regarding my question, the correlation between GDP and happiness is 0.81, which is very high.

# %% [markdown]
# Scatter plots to visually see how these variables move together

# %%
sns.scatterplot(x='Economy..GDP.per.Capita.', y='Happiness.Score', data= pd)

# %%
sns.scatterplot(x='Family', y='Happiness.Score', data= pd)

# %%
sns.scatterplot(x='Health..Life.Expectancy.', y='Happiness.Score', data= pd)

# %%
sns.scatterplot(x='Freedom', y='Happiness.Score', data= pd)

# %%
sns.scatterplot(x='Generosity', y='Happiness.Score', data= pd)

# %%
sns.scatterplot(x='Trust..Government.Corruption.', y='Happiness.Score', data= pd)

# %% [markdown]
# The scatter plots visually confirm the correlation values visually

# %% [markdown]
# In order to figure out what do happier countries value more compares to unhappier ones, I will see the means for the variables for the 25th and 75th percentile

# %%
pd['Percentile Rank'] = pd['Happiness.Rank'].rank(pct=True)

# %%
top25 = pd[pd['Percentile Rank']<.25].drop(['Happiness.Rank','Whisker.high','Whisker.low','Dystopia.Residual'],axis=1).describe().loc['mean']

# %%
low25 = pd[pd['Percentile Rank']>.75].drop(['Happiness.Rank','Whisker.high','Whisker.low','Dystopia.Residual'],axis=1).describe().loc['mean']

# %%
top25/low25
# Out:
# Happiness.Score                  1.752775
# Economy..GDP.per.Capita.         2.596837
# Family                           1.591378
# Health..Life.Expectancy.         2.634553
# Freedom                          1.773751
# Generosity                       1.320148
# Trust..Government.Corruption.    2.130762
# Percentile Rank                  0.143382
# Name: mean, dtype: float64

# %% [markdown]
# The code above returns the means for all the variables for the top and bottom 25% as a way to quantify how big is the gap for the variables between these two groups. I divided the top25 variables by the bottom 25 to get the ratios. The ratio for overall Happiness is 1.75x. When it comes to the component variables, the two that inmediately stick out to the upside are Economy and Health at over 2.5x. This makes perfect sense since there is such a big gap in economic output between these sets of groups must experience vastly different degrees of happiness from it. Health longevity and economy have the highest correlation of any two variables in the data set and we see that reflected here as well. The rest of the variables are more or less centered around 1.75x, but the low 25 clearly falls behind on all of them.

# %% [markdown]
# An interesting analysis would be to categorize the countries by continent, to see patterns that can differentiate the data points. This could be done by hand, but fortunately in the 2016 version of this data set the information is included as a variable. I could do this easily in Excel, but to practice I'll do it here instead

# %%
pd2016 = pd.read_csv('World Happiness 2016A.csv')

# %%
pd2016 = pd2016[['Country','Region']]

# %%
pd2016.head()
# Out:
#        Country          Region
# 0      Denmark  Western Europe
# 1  Switzerland  Western Europe
# 2      Iceland  Western Europe
# 3       Norway  Western Europe
# 4      Finland  Western Europe

# %%
pd2016.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 2 columns):
# Country    157 non-null object
# Region     157 non-null object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
results=pd.merge(pd2016, on='Country', how='left')

# %%
pd['Country']= pd['Country'].apply(lambda x: str(x))

# %%
pd2016['Country']= pd2016['Country'].apply(lambda x: str(x))

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 154
# Data columns (total 13 columns):
# Country                          155 non-null object
# Happiness.Rank                   155 non-null int64
# Happiness.Score                  155 non-null float64
# Whisker.high                     155 non-null float64
# Whisker.low                      155 non-null float64
# Economy..GDP.per.Capita.         155 non-null float64
# Family                           155 non-null float64
# Health..Life.Expectancy.         155 non-null float64
# Freedom                          155 non-null float64
# Generosity                       155 non-null float64
# Trust..Government.Corruption.    155 non-null float64
# Dystopia.Residual                155 non-null float64
# Region                           150 non-null object
# dtypes: float64(10), int64(1), object(2)
# memory usage: 17.0+ KB

# %% [markdown]
# #Not sure if the conversion to strings was neccesary, but the merger is done, with the addition of the region field from another dataframe assigned to each country. Now an analysis on a per region basis can be done

# %% [markdown]
# Seems like 5 countries didn't have a match in the pd2016 dataframe, so those have to be adjusted manually

# %%
results['Region'].unique()
# Out:
# array(['Western Europe', 'North America', 'Australia and New Zealand',
#        'Middle East and Northern Africa', 'Latin America and Caribbean',
#        'Central and Eastern Europe', 'Southeastern Asia', nan,
#        'Eastern Asia', 'Sub-Saharan Africa', 'Southern Asia'],
#       dtype=object)

# %%
results[results['Region'].isnull()]
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 32   Taiwan Province of China              33            6.422      6.494596
# 70    Hong Kong S.A.R., China              71            5.472      5.549594
# 112                Mozambique             113            4.550      4.774102
# 138                   Lesotho             139            3.808      4.044344
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 32      6.349404                  1.433627  1.384565
# 70      5.394406                  1.551675  1.262791
# 112     4.325898                  0.234306  0.870701
# 138     3.571656                  0.521021  1.190095
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 32                   0.793984  0.361467    0.258360
# 70                   0.943062  0.490969    0.374466
# ...

# %%
results.loc[32,'Region']='Eastern Asia'

# %%
results.loc[70,'Region']='Eastern Asia'

# %%
results.loc[112,'Region']='Sub-Saharan Africa'

# %%
results.loc[138,'Region']='Sub-Saharan Africa'

# %%
results.loc[154,'Region']='Sub-Saharan Africa'

# %%
results.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 0 to 154
# Data columns (total 13 columns):
# Country                          155 non-null object
# Happiness.Rank                   155 non-null int64
# Happiness.Score                  155 non-null float64
# Whisker.high                     155 non-null float64
# Whisker.low                      155 non-null float64
# Economy..GDP.per.Capita.         155 non-null float64
# Family                           155 non-null float64
# Health..Life.Expectancy.         155 non-null float64
# Freedom                          155 non-null float64
# Generosity                       155 non-null float64
# Trust..Government.Corruption.    155 non-null float64
# Dystopia.Residual                155 non-null float64
# Region                           155 non-null object
# dtypes: float64(10), int64(1), object(2)
# memory usage: 22.0+ KB

# %% [markdown]
# Dataframe is clean and ready to go!

# %%
results.groupby('Region').mean()['Happiness.Score'].sort_values(ascending=False)
# Out:
# Region
# Australia and New Zealand          7.299000
# North America                      7.154500
# Western Europe                     6.703714
# Latin America and Caribbean        5.957818
# Eastern Asia                       5.646667
# Southeastern Asia                  5.444875
# Central and Eastern Europe         5.409931
# Middle East and Northern Africa    5.369684
# Southern Asia                      4.628429
# Sub-Saharan Africa                 4.111949
# Name: Happiness.Score, dtype: float64

# %% [markdown]
# The Australia region and North America are the top 2 when it comes to happiness, Western Europe third and the rest ranking below, with Southern Asia and Sub-Saharan Africa significantly lower

# %%
results.groupby('Region').count()['Happiness.Score'].sort_values(ascending=False)
# Out:
# Region
# Sub-Saharan Africa                 39
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    19
# Southeastern Asia                   8
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Happiness.Score, dtype: int64

# %% [markdown]
# Something to note is that the populations in terms of countries for North America and the Australian region are very small compared to the rest of world, so that makes the metrics harder to compare.

# %%
sns.heatmap(results.groupby('Region').mean().drop(['Happiness.Rank','Happiness.Score','Whisker.high','Whisker.low','Dystopia.Residual'],axis=1),cmap='coolwarm', annot=True)

# %% [markdown]
# The biggest differences the heatmap shows are how much happiness the economy and family brings to people. As stated earlier, Australia, New Zealand, North America and Western Europe are ahead, while Southern Asia and Sub-Saharan Africa are far behind. An interesting observation is Eastern Asia being virtually right at the top of the health factor, while lagging on the remaining factors.
#
# When it comes to freedom, generosity and corruption, the range of values is much lower and not that much of contributors to the overall score, compared to the other 3.

# %%
g = sns.scatterplot(x='Economy..GDP.per.Capita.', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %%
g = sns.scatterplot(x='Family', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %%
g = sns.scatterplot(x='Health..Life.Expectancy.', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %%
g = sns.scatterplot(x='Freedom', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %%
g = sns.scatterplot(x='Generosity', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %%
g = sns.scatterplot(x='Trust..Government.Corruption.', y='Happiness.Score', data= results, hue='Region')
g.legend(loc='center right', bbox_to_anchor=(1.45, 0.5), ncol=1)

# %% [markdown]
# Overall, it seems to me that clustering by region for the various categories is clear, with some outliers of course. Even though the data set subjective and prone to bias, the results make sense when compared to my knowledge of the economies and situations across the globe.

# %% [markdown]
# When it comes to a future proposal for further research on this subject, it would be interesting to connect this data to other factors such as suicide rates (which are higher in developed countries, specially Scandinavia), income per capita, education, tax rates, etc. These factors are more quantifiable and can give a more accurate measure of how happiness is affected by them. My two main questions would be:
#
# 1) How can Scandinavia have such a high degree of happiness and at the same time have one of the highest suicide rates in the world?
#
# 2) How does an immigrant's perception of happiness change after moving to the US?
#
# To answer both questions a more detailed dataset would be needed, tracking individuals in both situations.
#
# In the case of Scandinavia, it would be useful to have a sample of people that consider themselves very happy and another of people that are depressed and compare the two in an expanded version of the factors in this study. With that information, we could analyze if the negative factors are systemic in those countries and if so, different national policies could be created to counter the negative effects.
#
# In the case of the immigrant moving to the US, it would be interesting to gather data from people in the process of migrating and following them through that journey until 5-10 years after their migration. I'd imagine that the economic factor of the score would be much higher, while the family could go up or down depending on the person's family situation, if the move was with or without the family.

# %% [markdown]
# Below are more visualizations, separating the previous scatter plots by region in different plots

# %%
g = sns.catplot(x='Economy..GDP.per.Capita.', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')

# %%
g = sns.catplot(x='Family', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')

# %%
g = sns.catplot(x='Health..Life.Expectancy.', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')

# %%
g = sns.catplot(x='Freedom', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')

# %%
g = sns.catplot(x='Generosity', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')

# %%
g = sns.catplot(x='Trust..Government.Corruption.', 
                   y='Happiness.Score', 
                   data=results, 
                   hue='Region',  # Color by stage
                   col='Region',  # Separate by stage
                   kind='swarm')
